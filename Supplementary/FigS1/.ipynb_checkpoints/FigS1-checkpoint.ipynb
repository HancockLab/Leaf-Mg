# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('810_Mg_blues_top3SNPs_wCoordinates_variables.csv')
df
# Out:
#      Accession_ID     Mg_blues chr5_21392702 chr5_21405867 chr5_282011  \
# 0              88  4381.237684             0             0           1
# 1             108  4249.456382             0             0           1
# 2             139  4489.038748             0             0           1
# 3             159  4812.735886             0             .           1
# 4             265  3798.743649             0             1           1
# ..            ...          ...           ...           ...         ...
# 805          9933  5149.871903             0             0           1
# 806          9938  4967.209695             0             0           1
# 807         10020  5158.205468             1             0           1
# 808         10022  4467.362925             0             1           1
# 809         10023  4881.726906             0             0           0
#
#      Latitude  Longitude       bio1      bio2       bio3  ...           K  \
# 0     47.4000   0.683333  11.829166  8.825000  37.875538  ...  226.204865
# 1     48.5167  -4.066670  11.100000  6.416667  37.745098  ...  201.766663
# 2     48.5167  -4.066670  11.100000  6.416667  37.745098  ...  201.766663
# 3     47.3500   3.933330   9.325000  7.700000  32.352940  ...  143.398697
# 4     44.6500  -1.166670  12.962500  9.558333  42.293510  ...  237.268997
# ..        ...        ...        ...       ...        ...  ...         ...
# 805   43.7400   3.890000  14.079166  9.141666  35.296009  ...  261.559998
# 806   50.6500   2.990000  10.345834  7.675000  34.417042  ...  149.106689
# 807   49.1700  16.500000   8.854167  8.458333  29.994089  ...  341.494598
# 808   48.0333   7.766700  10.783334  8.466667  32.816536  ...  208.210236
# 809   68.8000  15.450000        NaN       NaN        NaN  ...         NaN
#
#             N          P        ph       sand       silt     srad_mean  \
# 0    1.240112  36.844051  7.186786  51.225914  26.372322  11783.833008
# 1    2.772524  44.490234  6.174457  22.396698  60.273209  11146.583008
# 2    2.772524  44.490234  6.174457  22.396698  60.273209  11146.583008
# 3    2.195257  25.737415  5.862647  27.340385  48.445976  11838.916992
# 4    2.043349  10.124886  5.435710  70.752350  17.501411  12972.333008
# ..        ...        ...       ...        ...        ...           ...
# 805  1.598961  10.967125  6.837938  23.743881  41.265377  14307.000000
# 806  1.509961  49.417866  6.471595  28.846939  54.361046  10262.666992
# 807  1.553450  40.085613  7.549666  16.894424  59.226326  11056.916992
# 808  2.711020  36.571175  6.667569  22.351379  54.793911  11402.500000
# 809       NaN        NaN       NaN        NaN        NaN           NaN
#
#          ai  GRIDCODE         CLASSLIMIT
# 0    0.6404      38.0  44.8 - 48.2 mg/kg
# 1    1.2798      31.0  26.9 - 28.9 mg/kg
# 2    1.2798      31.0  26.9 - 28.9 mg/kg
# 3    0.9524      29.0  23.2 - 25.0 mg/kg
# 4    0.9147       NaN                NaN
# ..      ...       ...                ...
# 805  0.4689      44.0  69.5 - 74.8 mg/kg
# 806  0.8376      36.0  38.7 - 41.7 mg/kg
# 807  0.5385      53.0    134 - 144 mg/kg
# 808  0.9392      41.0  55.8 - 60.0 mg/kg
# 809     NaN       NaN                NaN
#
# [810 rows x 43 columns]

# %%
df.columns.to_list()
# Out:
# ['Accession_ID',
#  'Mg_blues',
#  'chr5_21392702',
#  'chr5_21405867',
#  'chr5_282011',
#  'Latitude',
#  'Longitude',
#  'bio1',
#  'bio2',
#  'bio3',
#  'bio4',
#  'bio5',
#  'bio6',
#  'bio7',
#  'bio8',
#  'bio9',
#  'bio10',
#  'bio11',
#  'bio12',
#  'bio13',
#  'bio14',
#  'bio15',
#  'bio16',
#  'bio17',
#  'bio18',
#  'bio19',
#  'awc',
#  'bulk_density',
#  'CaCO3',
#  'CEC',
#  'clay',
#  'CN',
#  'coarse_fragments',
#  'K',
#  'N',
#  'P',
#  'ph',
#  'sand',
#  'silt',
#  'srad_mean',
#  'ai',
#  'GRIDCODE',
#  'CLASSLIMIT']

# %%
df=df.rename(columns={'coarse_fragments':'coarse frag',
                      'bulk_density':'bulk density',
                      'CaCO3':'CaCO$_3$',
                      'ai':'AI',
                      'awc':'AWC',
                      'GRIDCODE':'Mg(Soil)',
                      'Mg_blues':'Mg(Leaf)',
                      'srad_mean':'srad',
                     })

# %%
df=df.drop(columns=['chr5_21392702',
                    'chr5_21405867',
                    'chr5_282011',
                    'CLASSLIMIT',
                    'Accession_ID'])
df
# Out:
#         Mg(Leaf)  Latitude  Longitude       bio1      bio2       bio3  \
# 0    4381.237684   47.4000   0.683333  11.829166  8.825000  37.875538
# 1    4249.456382   48.5167  -4.066670  11.100000  6.416667  37.745098
# 2    4489.038748   48.5167  -4.066670  11.100000  6.416667  37.745098
# 3    4812.735886   47.3500   3.933330   9.325000  7.700000  32.352940
# 4    3798.743649   44.6500  -1.166670  12.962500  9.558333  42.293510
# ..           ...       ...        ...        ...       ...        ...
# 805  5149.871903   43.7400   3.890000  14.079166  9.141666  35.296009
# 806  4967.209695   50.6500   2.990000  10.345834  7.675000  34.417042
# 807  5158.205468   49.1700  16.500000   8.854167  8.458333  29.994089
# 808  4467.362925   48.0333   7.766700  10.783334  8.466667  32.816536
# 809  4881.726906   68.8000  15.450000        NaN       NaN        NaN
#
#            bio4       bio5  bio6       bio7  ...  coarse frag           K  \
# 0    557.541077  25.500000   2.2  23.299999  ...    15.149744  226.204865
# 1    392.538361  20.799999   3.8  17.000000  ...    11.280096  201.766663
# 2    392.538361  20.799999   3.8  17.000000  ...    11.280096  201.766663
# 3    596.430664  22.700001  -1.1  23.800001  ...    25.592224  143.398697
# 4    483.411774  25.200001   2.6  22.600000  ...     7.823430  237.268997
# ..          ...        ...   ...        ...  ...          ...         ...
# 805  605.116272  28.400000   2.5  25.900000  ...    21.798716  261.559998
# 806  542.320190  23.100000   0.8  22.300001  ...     6.823482  149.106689
# 807  755.646790  24.200001  -4.0  28.200001  ...     9.075080  341.494598
# 808  660.266235  25.200001  -0.6  25.800001  ...     9.125873  208.210236
# 809         NaN        NaN   NaN        NaN  ...          NaN         NaN
#
#             N          P        ph       sand       silt          srad  \
# 0    1.240112  36.844051  7.186786  51.225914  26.372322  11783.833008
# 1    2.772524  44.490234  6.174457  22.396698  60.273209  11146.583008
# 2    2.772524  44.490234  6.174457  22.396698  60.273209  11146.583008
# 3    2.195257  25.737415  5.862647  27.340385  48.445976  11838.916992
# 4    2.043349  10.124886  5.435710  70.752350  17.501411  12972.333008
# ..        ...        ...       ...        ...        ...           ...
# 805  1.598961  10.967125  6.837938  23.743881  41.265377  14307.000000
# 806  1.509961  49.417866  6.471595  28.846939  54.361046  10262.666992
# 807  1.553450  40.085613  7.549666  16.894424  59.226326  11056.916992
# 808  2.711020  36.571175  6.667569  22.351379  54.793911  11402.500000
# 809       NaN        NaN       NaN        NaN        NaN           NaN
#
#          AI  Mg(Soil)
# 0    0.6404      38.0
# 1    1.2798      31.0
# 2    1.2798      31.0
# 3    0.9524      29.0
# 4    0.9147       NaN
# ..      ...       ...
# 805  0.4689      44.0
# 806  0.8376      36.0
# 807  0.5385      53.0
# 808  0.9392      41.0
# 809     NaN       NaN
#
# [810 rows x 38 columns]

# %%
df=df.dropna()
df
# Out:
#         Mg(Leaf)  Latitude  Longitude       bio1      bio2       bio3  \
# 0    4381.237684   47.4000   0.683333  11.829166  8.825000  37.875538
# 1    4249.456382   48.5167  -4.066670  11.100000  6.416667  37.745098
# 2    4489.038748   48.5167  -4.066670  11.100000  6.416667  37.745098
# 3    4812.735886   47.3500   3.933330   9.325000  7.700000  32.352940
# 5    5330.870503   46.6667   4.116670  10.720833  9.175000  35.562016
# ..           ...       ...        ...        ...       ...        ...
# 804  5226.664196   48.9100   4.520000  10.491667  9.450000  36.914062
# 805  5149.871903   43.7400   3.890000  14.079166  9.141666  35.296009
# 806  4967.209695   50.6500   2.990000  10.345834  7.675000  34.417042
# 807  5158.205468   49.1700  16.500000   8.854167  8.458333  29.994089
# 808  4467.362925   48.0333   7.766700  10.783334  8.466667  32.816536
#
#            bio4       bio5  bio6       bio7  ...  coarse frag           K  \
# 0    557.541077  25.500000   2.2  23.299999  ...    15.149744  226.204865
# 1    392.538361  20.799999   3.8  17.000000  ...    11.280096  201.766663
# 2    392.538361  20.799999   3.8  17.000000  ...    11.280096  201.766663
# 3    596.430664  22.700001  -1.1  23.800001  ...    25.592224  143.398697
# 5    621.583252  25.400000  -0.4  25.799999  ...    12.934365  237.669601
# ..          ...        ...   ...        ...  ...          ...         ...
# 804  595.848633  25.299999  -0.3  25.599998  ...    15.485302  288.782288
# 805  605.116272  28.400000   2.5  25.900000  ...    21.798716  261.559998
# 806  542.320190  23.100000   0.8  22.300001  ...     6.823482  149.106689
# 807  755.646790  24.200001  -4.0  28.200001  ...     9.075080  341.494598
# 808  660.266235  25.200001  -0.6  25.800001  ...     9.125873  208.210236
#
#             N          P        ph       sand       silt          srad  \
# 0    1.240112  36.844051  7.186786  51.225914  26.372322  11783.833008
# 1    2.772524  44.490234  6.174457  22.396698  60.273209  11146.583008
# 2    2.772524  44.490234  6.174457  22.396698  60.273209  11146.583008
# 3    2.195257  25.737415  5.862647  27.340385  48.445976  11838.916992
# 5    1.743629  36.619621  6.276878  31.822845  43.187374  12031.583008
# ..        ...        ...       ...        ...        ...           ...
# 804  1.758133  48.285244  7.874985  22.354774  48.579197  11090.416992
# 805  1.598961  10.967125  6.837938  23.743881  41.265377  14307.000000
# 806  1.509961  49.417866  6.471595  28.846939  54.361046  10262.666992
# 807  1.553450  40.085613  7.549666  16.894424  59.226326  11056.916992
# 808  2.711020  36.571175  6.667569  22.351379  54.793911  11402.500000
#
#          AI  Mg(Soil)
# 0    0.6404      38.0
# 1    1.2798      31.0
# 2    1.2798      31.0
# 3    0.9524      29.0
# 5    0.7753      36.0
# ..      ...       ...
# 804  0.7287      32.0
# 805  0.4689      44.0
# 806  0.8376      36.0
# 807  0.5385      53.0
# 808  0.9392      41.0
#
# [579 rows x 38 columns]

# %%
fig = plt.figure(figsize=(20,20))
mask = np.triu(np.ones_like(df.corr(), dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df.corr(method='spearman'), 
            mask=mask, 
            vmax=1, 
            vmin=-1,
            center=0, 
            cmap='bwr',
            square=True, 
            annot=True,
            fmt=".1f",
            linewidths=.2, 
            cbar_kws={"shrink": .5})
plt.savefig("FigS1.pdf", format="pdf",facecolor="w",bbox_inches="tight")

# %%
df.corr().to_csv('correlation.txt',sep='\t')

# %%
r=df.corr(method='spearman').abs().unstack().sort_values()

# %%
r[1430:len(r)-39]
# Out:
# bio17     AI          0.775287
# AI        bio17       0.775287
# AWC       clay        0.782944
# clay      AWC         0.782944
# bio4      bio7        0.785308
# bio7      bio4        0.785308
# AI        bio14       0.795347
# bio14     AI          0.795347
# bio1      bio6        0.796929
# bio6      bio1        0.796929
# AI        bio5        0.801972
# bio5      AI          0.801972
# bio9      bio6        0.805205
# bio6      bio9        0.805205
# bio1      latitude    0.819502
# latitude  bio1        0.819502
# bio9      bio11       0.828505
# bio11     bio9        0.828505
# srad      bio10       0.836265
# bio10     srad        0.836265
# bio5      bio2        0.839165
# bio2      bio5        0.839165
# bio12     bio13       0.839296
# bio13     bio12       0.839296
# bio1      bio5        0.855345
# bio5      bio1        0.855345
# latitude  bio10       0.855992
# bio10     latitude    0.855992
# clay      sand        0.864222
# sand      clay        0.864222
# bio16     bio12       0.874886
# bio12     bio16       0.874886
# srad      bio5        0.895711
# bio5      srad        0.895711
# latitude  bio5        0.899571
# bio5      latitude    0.899571
# bio1      bio10       0.912463
# bio10     bio1        0.912463
# bio1      bio11       0.918859
# bio11     bio1        0.918859
# silt      sand        0.946736
# sand      silt        0.946736
# bio6      bio11       0.947870
# bio11     bio6        0.947870
# bio10     bio5        0.963232
# bio5      bio10       0.963232
# srad      latitude    0.966574
# latitude  srad        0.966574
# bio17     bio14       0.969796
# bio14     bio17       0.969796
# bio16     bio13       0.981969
# bio13     bio16       0.981969
# dtype: float64

# %%
len(r)
# Out:
# 1521

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
selector = VarianceThreshold()
selector.fit_transform(df)
# Out:
# array([[ 6.42521703e+03,  5.59473000e+01,  1.38210000e+01, ...,
#          3.48819313e+01,  9.90431976e+01,  3.70000000e+01],
#        [ 6.10609055e+03,  5.57714000e+01,  1.41208000e+01, ...,
#          4.39168510e+01,  1.28464050e+02,  4.00000000e+01],
#        [ 5.93766764e+03,  4.94112000e+01,  1.62815000e+01, ...,
#          3.88841705e+01,  2.05518021e+02,  4.70000000e+01],
#        ...,
#        [ 3.70034249e+03,  4.05700000e+01, -3.89000000e+00, ...,
#          3.20507507e+01,  2.34559372e+02,  6.30000000e+01],
#        [ 3.64480836e+03,  3.97200000e+01, -6.89000000e+00, ...,
#          1.04898748e+01,  2.45356354e+02,  3.50000000e+01],
#        [ 3.58994320e+03,  3.86000000e+01, -2.70000000e+00, ...,
#          6.96726513e+00,  2.57971314e+02,  4.60000000e+01]])

# %%
for feature in zip(df.columns, selector.variances_):
    print(feature)
# Out:
# ('Mg(Leaf)', 2835.273831)
# ('latitude', 26.564)
# ('longitude', 34.16)
# ('bio1', 9.086283752834282)
# ('bio2', 2.977901103307877)
# ('bio3', 18.47504212756497)
# ('bio4', 543.1307983)
# ('bio5', 14.641156280306488)
# ('bio6', 11.740884610030335)
# ('bio7', 13.347691597271)
# ('bio8', 23.283333536)
# ('bio9', 29.533333302)
# ('bio10', 8.490458923958844)
# ('bio11', 13.006640975246487)
# ('bio12', 2003.0)
# ('bio13', 257.0)
# ('bio14', 123.0)
# ('bio15', 68.459264752)
# ('bio16', 702.0)
# ('bio17', 374.0)
# ('bio18', 474.0)
# ('bio19', 715.0)
# ('wind', 1.0784898314106899)
# ('srad', 9572.75)
# ('AI', 0.150844850208011)
# ('AWC', 0.00024777048017464405)
# ('bulk density', 0.023784564905715153)
# ('clay', 41.18974364)
# ('coarse frag', 35.891673561000005)
# ('sand', 90.510627746)
# ('silt', 73.31703949000001)
# ('pH', 0.7000370777420115)
# ('CN', 13.580967848833097)
# ('CEC', 31.944904597906245)
# ('CaCO$_3$', 414.7425842)
# ('N', 0.719153869037431)
# ('P', 72.793797969)
# ('K', 788.67099376)
# ('Mg(Soil)', 51.0)

# %%
df.colunms()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-855911c72daf> in <module>
# ----> 1 df.colunms()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'colunms'

# %%
r[1470:]
# Out:
# silt          sand            0.946736
# sand          silt            0.946736
# bio6          bio11           0.947870
# bio11         bio6            0.947870
# bio10         bio5            0.963232
# bio5          bio10           0.963232
# srad          latitude        0.966574
# latitude      srad            0.966574
# bio17         bio14           0.969796
# bio14         bio17           0.969796
# bio16         bio13           0.981969
# bio13         bio16           0.981969
# Mg(Leaf)      Mg(Leaf)        1.000000
# bio17         bio17           1.000000
# P             P               1.000000
# bio13         bio13           1.000000
# bio12         bio12           1.000000
# bio11         bio11           1.000000
# bio10         bio10           1.000000
# bio9          bio9            1.000000
# bio8          bio8            1.000000
# bio7          bio7            1.000000
# bio6          bio6            1.000000
# bio5          bio5            1.000000
# bio4          bio4            1.000000
# bio3          bio3            1.000000
# bio2          bio2            1.000000
# bio1          bio1            1.000000
# longitude     longitude       1.000000
# latitude      latitude        1.000000
# bio14         bio14           1.000000
# K             K               1.000000
# bio15         bio15           1.000000
# bio18         bio18           1.000000
# N             N               1.000000
# CaCO$_3$      CaCO$_3$        1.000000
# CEC           CEC             1.000000
# CN            CN              1.000000
# pH            pH              1.000000
# silt          silt            1.000000
# sand          sand            1.000000
# coarse frag   coarse frag     1.000000
# clay          clay            1.000000
# bulk density  bulk density    1.000000
# AWC           AWC             1.000000
# AI            AI              1.000000
# srad          srad            1.000000
# wind          wind            1.000000
# bio19         bio19           1.000000
# bio16         bio16           1.000000
# Mg(Soil)      Mg(Soil)        1.000000
# dtype: float64

# %%
from scipy.stats import spearmanr
spearmanr(df['latitude'],df['srad'])
# Out:
# SpearmanrResult(correlation=-0.9665738933310937, pvalue=0.0)

# %%
from scipy.stats import pearsonr
pearsonr(df['latitude'],df['srad'])
# Out:
# (-0.9290870655001064, 8.811575592545262e-294)
