# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_table('Europe_677_accession.txt')
df.head()
# Out:
#           Mg25  Latitude  Longitude       bio1      bio2       bio3  \
# 0  6425.217028   55.9473    13.8210   6.800000  7.100000  29.831934
# 1  6106.090545   55.7714    14.1208   7.400000  6.966667  29.645391
# 2  5937.667641   49.4112    16.2815   7.395833  8.241667  30.079075
# 3  5936.194976   55.4234    13.9905   7.937500  6.741666  28.566383
# 4  5842.619693   50.0667     8.5333  10.337500  8.458333  32.532051
#
#          bio4       bio5  bio6       bio7  ...       silt        ph  \
# 0  632.671082  20.400000  -3.4  23.799999  ...  26.771446  5.099498
# 1  620.901123  21.000000  -2.5  23.500000  ...  18.155411  5.306688
# 2  733.808411  22.500000  -4.9  27.400000  ...  37.807838  5.724783
# 3  631.276184  21.299999  -2.3  23.599998  ...  21.127319  6.321225
# 4  672.647827  25.100000  -0.9  26.000000  ...  27.917473  6.733436
#
#           CN        CEC      CaCO3         N          P           K  \
# 0  16.017828  11.404053   8.995235  2.903223  34.881931   99.043198
# 1  16.933012  11.273796  11.339157  2.775039  43.916851  128.464050
# 2  10.382457  11.531424   0.000000  2.134119  38.884171  205.518021
# 3  11.384063  13.246228  10.353964  2.153087  56.946087  138.103867
# 4  13.335432  11.836184  54.417881  1.570549  32.795654  158.965622
#
#    Mg_MMI_07  Mg_MMI_72
# 0        2.0       37.0
# 1        3.0       40.0
# 2        3.0       47.0
# 3        2.0       39.0
# 4        3.0       43.0
#
# [5 rows x 41 columns]

# %%
fig = plt.figure(figsize=(20,20))
mask = np.triu(np.ones_like(df.corr(), dtype=bool))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df.corr(method='spearman'), 
            mask=mask, 
            vmax=1, 
            vmin=-1,
            center=0, 
            cmap='bwr',
            square=True, 
            annot=True,
            fmt=".1f",
            linewidths=.2, 
            cbar_kws={"shrink": .5})
# plt.savefig("FigS1.pdf", format="pdf",facecolor="w",bbox_inches="tight")
# Out:
# <AxesSubplot:>
