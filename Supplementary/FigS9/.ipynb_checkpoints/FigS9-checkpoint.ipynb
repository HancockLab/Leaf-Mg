# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker
from scipy.stats import mannwhitneyu
import matplotlib.patches as mpl_patches

# %% [markdown]
# # Import 1135 leaf ionome dataset

# %%
df_1001=pd.read_table('1135_leaf_ionome.txt')
df_1001.head()
# Out:
#    Accession_ID    Name Country  Latitude  Longitude CS_number material  \
# 0            88     CYR  France   47.4000   0.683333   CS76790     leaf
# 1           108  LDV-18  France   48.5167  -4.066670   CS77013     leaf
# 2           139  LDV-46  France   48.5167  -4.066670   CS77014     leaf
# 3           159  MAR2-3  France   47.3500   3.933330   CS77070     leaf
# 4           265   PYL-6  France   44.6500  -1.166670   CS77198     leaf
#
#   material_Country        Li7         Na23  ...        Fe57      Co59  \
# 0      France_leaf  13.533427  1989.385107  ...  138.401580  1.827647
# 1      France_leaf  15.194267  2189.845711  ...  139.236192  2.404636
# 2      France_leaf  14.933369  1898.967428  ...  138.563407  2.078383
# 3      France_leaf  13.951764   728.667266  ...  137.832993  1.843778
# 4      France_leaf  13.954460   944.421617  ...  142.203851  2.545781
#
#        Cu65        Zn66      As75       Se82        Rb85       Sr88  \
# 0  7.052531   98.274997  1.151200  71.442057  391.846982  62.937324
# 1  8.692987  101.369937  0.961746  80.210170  352.172133  67.492959
# 2  9.324010   90.119590  1.000845  80.952731  366.533365  66.630082
# 3  7.985748   89.160879  0.979777  83.333572  483.749994  62.559302
# 4  9.120528   91.621874  1.279418  65.267342  386.146591  65.702393
#
#         Mo98     Cd114
# 0   5.052709  2.448871
# 1   5.875919  2.932134
# 2   4.893860  2.737883
# 3   5.164345  2.349769
# 4  22.864612  2.725846
#
# [5 rows x 26 columns]

# %%
Europe.shape
# Out:
# (959, 26)

# %%
df_1001.loc[df_1001['Name'] == 'Col-0']['Mg25']
# Out:
# 251    5713.700234
# Name: Mg25, dtype: float64

# %%
df_1001['Mg/Col-0']=df_1001['Mg25']/df_1001.loc[df_1001['Name'] == 'Col-0','Mg25'].item()
df_1001.head()
# Out:
#    Accession_ID    Name Country  Latitude  Longitude CS_number material  \
# 0            88     CYR  France   47.4000   0.683333   CS76790     leaf
# 1           108  LDV-18  France   48.5167  -4.066670   CS77013     leaf
# 2           139  LDV-46  France   48.5167  -4.066670   CS77014     leaf
# 3           159  MAR2-3  France   47.3500   3.933330   CS77070     leaf
# 4           265   PYL-6  France   44.6500  -1.166670   CS77198     leaf
#
#   material_Country        Li7         Na23  ...      Co59      Cu65  \
# 0      France_leaf  13.533427  1989.385107  ...  1.827647  7.052531
# 1      France_leaf  15.194267  2189.845711  ...  2.404636  8.692987
# 2      France_leaf  14.933369  1898.967428  ...  2.078383  9.324010
# 3      France_leaf  13.951764   728.667266  ...  1.843778  7.985748
# 4      France_leaf  13.954460   944.421617  ...  2.545781  9.120528
#
#          Zn66      As75       Se82        Rb85       Sr88       Mo98  \
# 0   98.274997  1.151200  71.442057  391.846982  62.937324   5.052709
# 1  101.369937  0.961746  80.210170  352.172133  67.492959   5.875919
# 2   90.119590  1.000845  80.952731  366.533365  66.630082   4.893860
# 3   89.160879  0.979777  83.333572  483.749994  62.559302   5.164345
# 4   91.621874  1.279418  65.267342  386.146591  65.702393  22.864612
#
#       Cd114  Mg/Col-0
# 0  2.448871  0.789994
# 1  2.932134  0.777822
# 2  2.737883  0.796113
# 3  2.349769  0.841582
# 4  2.725846  0.718132
#
# [5 rows x 27 columns]

# %% [markdown]
# # Filter for European accessions

# %%
Europe=df_1001.loc[(df_1001['Latitude']>36.52) & (df_1001['Latitude']<68.80) & (df_1001['Longitude']>-8.54) & (df_1001['Longitude']<38.28)]
Europe.head()
# Out:
#    Accession_ID    Name Country  Latitude  Longitude CS_number material  \
# 0            88     CYR  France   47.4000   0.683333   CS76790     leaf
# 1           108  LDV-18  France   48.5167  -4.066670   CS77013     leaf
# 2           139  LDV-46  France   48.5167  -4.066670   CS77014     leaf
# 3           159  MAR2-3  France   47.3500   3.933330   CS77070     leaf
# 4           265   PYL-6  France   44.6500  -1.166670   CS77198     leaf
#
#   material_Country        Li7         Na23  ...      Co59      Cu65  \
# 0      France_leaf  13.533427  1989.385107  ...  1.827647  7.052531
# 1      France_leaf  15.194267  2189.845711  ...  2.404636  8.692987
# 2      France_leaf  14.933369  1898.967428  ...  2.078383  9.324010
# 3      France_leaf  13.951764   728.667266  ...  1.843778  7.985748
# 4      France_leaf  13.954460   944.421617  ...  2.545781  9.120528
#
#          Zn66      As75       Se82        Rb85       Sr88       Mo98  \
# 0   98.274997  1.151200  71.442057  391.846982  62.937324   5.052709
# 1  101.369937  0.961746  80.210170  352.172133  67.492959   5.875919
# 2   90.119590  1.000845  80.952731  366.533365  66.630082   4.893860
# 3   89.160879  0.979777  83.333572  483.749994  62.559302   5.164345
# 4   91.621874  1.279418  65.267342  386.146591  65.702393  22.864612
#
#       Cd114  Mg/Col-0
# 0  2.448871  0.789994
# 1  2.932134  0.777822
# 2  2.737883  0.796113
# 3  2.349769  0.841582
# 4  2.725846  0.718132
#
# [5 rows x 27 columns]

# %%
Europe.shape
# Out:
# (959, 27)

# %%
Europe_Mg=Europe[['Accession_ID','Name','Mg25','Mg/Col-0']]
Europe_Mg.head()
# Out:
#    Accession_ID    Name         Mg25  Mg/Col-0
# 0            88     CYR  4513.790113  0.789994
# 1           108  LDV-18  4444.244161  0.777822
# 2           139  LDV-46  4548.751871  0.796113
# 3           159  MAR2-3  4808.545837  0.841582
# 4           265   PYL-6  4103.189376  0.718132

# %%
Europe_Mg=Europe_Mg.rename(columns={'Accession_ID':'Seq_ID',
                   'Name':'Sample_ID',
                   'Mg25':'Mg'})
Europe_Mg.head()
# Out:
#    Seq_ID Sample_ID           Mg  Mg/Col-0
# 0      88       CYR  4513.790113  0.789994
# 1     108    LDV-18  4444.244161  0.777822
# 2     139    LDV-46  4548.751871  0.796113
# 3     159    MAR2-3  4808.545837  0.841582
# 4     265     PYL-6  4103.189376  0.718132

# %%
Europe_Mg['Population']='Europe'
Europe_Mg.head()
# Out:
#    Seq_ID Sample_ID           Mg  Mg/Col-0 Population
# 0      88       CYR  4513.790113  0.789994     Europe
# 1     108    LDV-18  4444.244161  0.777822     Europe
# 2     139    LDV-46  4548.751871  0.796113     Europe
# 3     159    MAR2-3  4808.545837  0.841582     Europe
# 4     265     PYL-6  4103.189376  0.718132     Europe

# %% [markdown]
# # Import Santo Antao leaf ionome dataset

# %%
SA=pd.read_table('SantoAntao_jiffy_20240307.txt')
SA.head()
# Out:
#     Seq_ID Sample_ID     Mg24
# 0    22615    S1-100  2624.01
# 1    22628   S10-100  3146.22
# 2  2876_AM   S10-101  3038.21
# 3    22637   S10-102  3065.45
# 4    27158    S10-12  2601.31

# %%
SA.shape
# Out:
# (109, 3)

# %%
SA['Mg/Col-0']=SA['Mg24']/SA.loc[SA['Sample_ID'] == 'Col-0','Mg24'].item()
SA.head()
# Out:
#     Seq_ID Sample_ID     Mg24  Mg/Col-0
# 0    22615    S1-100  2624.01  0.676946
# 1    22628   S10-100  3146.22  0.811666
# 2  2876_AM   S10-101  3038.21  0.783801
# 3    22637   S10-102  3065.45  0.790829
# 4    27158    S10-12  2601.31  0.671089

# %%
SA=SA.rename(columns={'Mg24':'Mg'})
SA.head()
# Out:
#     Seq_ID Sample_ID       Mg  Mg/Col-0
# 0    22615    S1-100  2624.01  0.676946
# 1    22628   S10-100  3146.22  0.811666
# 2  2876_AM   S10-101  3038.21  0.783801
# 3    22637   S10-102  3065.45  0.790829
# 4    27158    S10-12  2601.31  0.671089

# %%
SA['Population']='SA'
SA.head()
# Out:
#     Seq_ID Sample_ID       Mg  Mg/Col-0 Population
# 0    22615    S1-100  2624.01  0.676946         SA
# 1    22628   S10-100  3146.22  0.811666         SA
# 2  2876_AM   S10-101  3038.21  0.783801         SA
# 3    22637   S10-102  3065.45  0.790829         SA
# 4    27158    S10-12  2601.31  0.671089         SA

# %% [markdown]
# # Combine datasets

# %%
combined=pd.concat([Europe_Mg,SA])
combined.head()
# Out:
#   Seq_ID Sample_ID           Mg  Mg/Col-0 Population
# 0     88       CYR  4513.790113  0.789994     Europe
# 1    108    LDV-18  4444.244161  0.777822     Europe
# 2    139    LDV-46  4548.751871  0.796113     Europe
# 3    159    MAR2-3  4808.545837  0.841582     Europe
# 4    265     PYL-6  4103.189376  0.718132     Europe

# %% [markdown]
# ### Remove Col-0 and Cvi-0

# %%
combined_noColO_Cvi=combined.loc[(combined['Sample_ID'] != 'Col-0') | (combined['Sample_ID'] != 'Cvi-0')]
combined_noColO_Cvi.head()
# Out:
#   Seq_ID Sample_ID           Mg  Mg/Col-0 Population
# 0     88       CYR  4513.790113  0.789994     Europe
# 1    108    LDV-18  4444.244161  0.777822     Europe
# 2    139    LDV-46  4548.751871  0.796113     Europe
# 3    159    MAR2-3  4808.545837  0.841582     Europe
# 4    265     PYL-6  4103.189376  0.718132     Europe

# %%
boxprops = {'edgecolor': 'black', 'linewidth': 0.5, 'facecolor': 'grey'}
lineprops = {'color': 'k', 'linewidth': 0.5}
boxplot_kwargs = dict({'boxprops': boxprops, 'medianprops': lineprops,
                       'whiskerprops': lineprops, 'capprops': lineprops,
                       'width': 0.6})

europe=combined[combined_noColO_Cvi['Population'] == 'Europe']
santoantao=combined[combined_noColO_Cvi['Population'] == 'SA']

Order=['SA','Europe']

@ticker.FuncFormatter
def major_formatter(x, pos):
    y = x /1000000
    return "%.0f" % y
cm = 1/2.54
plt.figure(figsize=(6*cm,5*cm))
ax=sns.violinplot(x='Population', 
            y='Mg/Col-0',
            color='grey',
            data=combined,
            order=Order,
            linewidth=1.5,
            fliersize=0,
            **boxplot_kwargs)
r,p = mannwhitneyu(europe['Mg/Col-0'],santoantao['Mg/Col-0'])
handles = [mpl_patches.Rectangle((0, 0), 1, 1, fc="white", ec="white", 
                                 lw=0, alpha=0)] * 2
labels=[]
labels.append(r"$P$ = {:.2e}".format(p))
plt.legend(handles, labels, loc='upper left', fontsize=8, 
      fancybox=True, framealpha=0.7, 
      handlelength=0, handletextpad=0)
ax.set_xticklabels(['Santo Antao', 'Europe'])

sns.despine(trim=True,offset=10)
plt.tick_params(labelsize=8)
plt.savefig("FigS8.pdf", format="pdf",bbox_inches="tight",facecolor="w")
plt.savefig("FigS8.png", format="png",bbox_inches="tight",facecolor="w",dpi=400)

# %%
combined.head()
# Out:
#   Seq_ID Sample_ID           Mg  Mg/Col-0 Population
# 0     88       CYR  4513.790113  0.789994     Europe
# 1    108    LDV-18  4444.244161  0.777822     Europe
# 2    139    LDV-46  4548.751871  0.796113     Europe
# 3    159    MAR2-3  4808.545837  0.841582     Europe
# 4    265     PYL-6  4103.189376  0.718132     Europe

# %%
combined.to_csv('FigS8.txt',sep='\t',index=None,header=True)
