# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.stats import spearmanr

# %%
df = pd.read_table('Fig1b.txt')
df
# Out:
#      Accession_ID  Mg_blues (µg/g DW)  Latitude  Longitude       bio1  \
# 0              88         4381.237684   47.4000   0.683333  11.829166
# 1             108         4249.456382   48.5167  -4.066670  11.100000
# 2             139         4489.038748   48.5167  -4.066670  11.100000
# 3             159         4812.735886   47.3500   3.933330   9.325000
# 4             265         3798.743649   44.6500  -1.166670  12.962500
# ..            ...                 ...       ...        ...        ...
# 805          9933         5149.871903   43.7400   3.890000  14.079166
# 806          9938         4967.209695   50.6500   2.990000  10.345834
# 807         10020         5158.205468   49.1700  16.500000   8.854167
# 808         10022         4467.362925   48.0333   7.766700  10.783334
# 809         10023         4881.726906   68.8000  15.450000        NaN
#
#          bio2       bio3        bio4       bio5  bio6  ...  coarse_fragments  \
# 0    8.825000  37.875538  557.541077  25.500000   2.2  ...         15.149744
# 1    6.416667  37.745098  392.538361  20.799999   3.8  ...         11.280096
# 2    6.416667  37.745098  392.538361  20.799999   3.8  ...         11.280096
# 3    7.700000  32.352940  596.430664  22.700001  -1.1  ...         25.592224
# 4    9.558333  42.293510  483.411774  25.200001   2.6  ...          7.823430
# ..        ...        ...         ...        ...   ...  ...               ...
# 805  9.141666  35.296009  605.116272  28.400000   2.5  ...         21.798716
# 806  7.675000  34.417042  542.320190  23.100000   0.8  ...          6.823482
# 807  8.458333  29.994089  755.646790  24.200001  -4.0  ...          9.075080
# 808  8.466667  32.816536  660.266235  25.200001  -0.6  ...          9.125873
# 809       NaN        NaN         NaN        NaN   NaN  ...               NaN
#
#               K         N          P        ph       sand       silt  \
# 0    226.204865  1.240112  36.844051  7.186786  51.225914  26.372322
# 1    201.766663  2.772524  44.490234  6.174457  22.396698  60.273209
# 2    201.766663  2.772524  44.490234  6.174457  22.396698  60.273209
# 3    143.398697  2.195257  25.737415  5.862647  27.340385  48.445976
# 4    237.268997  2.043349  10.124886  5.435710  70.752350  17.501411
# ..          ...       ...        ...       ...        ...        ...
# 805  261.559998  1.598961  10.967125  6.837938  23.743881  41.265377
# 806  149.106689  1.509961  49.417866  6.471595  28.846939  54.361046
# 807  341.494598  1.553450  40.085613  7.549666  16.894424  59.226326
# 808  208.210236  2.711020  36.571175  6.667569  22.351379  54.793911
# 809         NaN       NaN        NaN       NaN        NaN        NaN
#
#        srad_mean      ai  Mg(Soil) mg/kg
# 0    11783.83301  0.6404            38.0
# 1    11146.58301  1.2798            31.0
# 2    11146.58301  1.2798            31.0
# 3    11838.91699  0.9524            29.0
# 4    12972.33301  0.9147             NaN
# ..           ...     ...             ...
# 805  14307.00000  0.4689            44.0
# 806  10262.66699  0.8376            36.0
# 807  11056.91699  0.5385            53.0
# 808  11402.50000  0.9392            41.0
# 809          NaN     NaN             NaN
#
# [810 rows x 39 columns]

# %%
df=df.dropna(subset=['Latitude'])

# %%
from matplotlib.ticker import MaxNLocator
import matplotlib.ticker as ticker
cm=1/2.54
# fig,axes = plt.subplots(figsize=(8*cm,5*cm))
fig = plt.figure(figsize=(9*cm,8*cm))
ax = sns.scatterplot(data=df,
            x='Latitude',
            y='Mg_blues (µg/g DW)',
            color='grey',
            edgecolor='none',
            marker='o',
            s=50,
            alpha=0.7)
r,p = spearmanr(df['Mg_blues (µg/g DW)'],df['Latitude'])
plt.text(10, 5800, '$\itR$ = {:.2f}\n$P$ = {:.2e}\n$n$ = {}'.format(r,p,df.shape[0]), fontsize=12)
# plt.ylim(3000,7000)
# plt.xlim(3200,7000)
plt.ylabel('Leaf [Mg] (µg/g DW)',fontsize=10)
ax.set_xlim(10,70)
# plt.xlabel()
ax.xaxis.set_major_locator(ticker.MultipleLocator(10))
# ax.yaxis.set_major_locator(ticker.MultipleLocator(15))
sns.despine(offset=10, trim=True)
plt.savefig("Fig1b.pdf", format="pdf",bbox_inches="tight",facecolor='w')
